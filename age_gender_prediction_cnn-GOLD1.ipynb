# %% [markdown]
# # Age and Gender Prediction

# %% [markdown]
# ### Dataset: https://www.kaggle.com/datasets/nipunarora8/age-gender-and-ethnicity-face-data-csv

# %% [markdown]
# ### Tensorflow – Developed by Google, this open-source library is used for creating Deep learning models. It provides many methods to interpret data but mainly focuses on training and inference of Neural Networks

# %%
# importing necessary libraries
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import keras
from keras import layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading the Dataset
# The dataset used here was in a csv format. We used Pandas to read the csv file and print the shape and information about the dataset.

# %%
# reading the dataset
df= pd.read_csv('age_gender.csv')
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...

# %%
# information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23705 entries, 0 to 23704
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        23705 non-null  int64
#  1   ethnicity  23705 non-null  int64
#  2   gender     23705 non-null  int64
#  3   img_name   23705 non-null  object
#  4   pixels     23705 non-null  object
# dtypes: int64(3), object(2)
# memory usage: 926.1+ KB

# %% [markdown]
# # EDA

# %%
# Visualize distributions
fig, axes = plt.subplots(1, 3, figsize=(15, 5))
df['age'].hist(ax=axes[0])
axes[0].set_title('Age Distribution')
axes[0].set_xlabel('Age')

df['ethnicity'].hist(ax=axes[1])
axes[1].set_title('Ethnicity Distribution')
axes[1].set_xlabel('Ethnicity')

df['gender'].hist(ax=axes[2])
axes[2].set_title('Gender Distribution')
axes[2].set_xlabel('Gender')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Filter data for male and female separately
male_data = df[df['gender'] == 0]
female_data = df[df['gender'] == 1]

# Plot the distributions of age for male and female
plt.figure(figsize=(10, 6))
sns.kdeplot(data=male_data['age'], label='Male', fill=True)
sns.kdeplot(data=female_data['age'], label='Female', fill=True)
plt.title('Distribution of Age by Gender')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# # Feature Engineering & Transformations
# We are concerned about the pixels column in the dataframe. But the values in that column are an object type data type. To convert the datatype of the column, we will define a function which adheres to our purpose at hand and then apply it to create a new column.

# %%
# creating a fuctio which will change the datatype to an array
def str_to_array(ob):
	return np.array(ob.split(' '), dtype='int')

# apply the function to pixels column and create a new column 'new_pixels'
df['new_pixels'] = df['pixels'].apply(str_to_array)

# %%
df.head()
# Out:
#    age  ethnicity  gender                        img_name  \
# 0    1          2       0  20161219203650636.jpg.chip.jpg
# 1    1          2       0  20161219222752047.jpg.chip.jpg
# 2    1          2       0  20161219222832191.jpg.chip.jpg
# 3    1          2       0  20161220144911423.jpg.chip.jpg
# 4    1          2       0  20161220144914327.jpg.chip.jpg
#
#                                               pixels  \
# 0  129 128 128 126 127 130 133 135 139 142 145 14...
# 1  164 74 111 168 169 171 175 182 184 188 193 199...
# 2  67 70 71 70 69 67 70 79 90 103 116 132 145 155...
# 3  193 197 198 200 199 200 202 203 204 205 208 21...
# 4  202 205 209 210 209 209 210 211 212 214 218 21...
#
#                                           new_pixels
# 0  [129, 128, 128, 126, 127, 130, 133, 135, 139, ...
# 1  [164, 74, 111, 168, 169, 171, 175, 182, 184, 1...
# 2  [67, 70, 71, 70, 69, 67, 70, 79, 90, 103, 116,...
# 3  [193, 197, 198, 200, 199, 200, 202, 203, 204, ...
# 4  [202, 205, 209, 210, 209, 209, 210, 211, 212, ...

# %%
len(df['new_pixels'][0])
# Out:
# 2304

# %%
df.shape
# Out:
# (23705, 6)

# %% [markdown]
# # Check the input Face images - the given data
# To visualize an Image, we are first generating a list of random indices value from the dataset and using that to plot a subplot of images. To plot the image we have to first reshape the data into a (48,48,1) shape.

# %%
# creating an empty 3x5 subplot
fig, ax = plt.subplots(3, 5, figsize=(12, 7))
ax = ax.ravel()

# generating a random list of integers
res = random.sample(range(0, df.shape[0]), 15)

print (res)

# creating the subplot for random images and printing the corresponding gender and age
for i, id in enumerate(res):
	ax[i].imshow(df['new_pixels'].loc[id].reshape(48, 48))
	ax[i].set_title(f'Age:{df.age.loc[id]}, Gender:{df.gender.loc[id]}')
	ax[i].axis('off')

plt.savefig('image_visualization_subplot.png')
# Out:
# [4110, 14379, 20546, 15335, 9198, 22535, 13389, 752, 1081, 16117, 13200, 8047, 18224, 4392, 784]

# %% [markdown]
# # Model Building
# To start with creating the model, we first expand the new pixels column to make a dataframe. Using that dataframe and necessary target values (age and gender), we will split our dataset into training and Validation Dataset.

# %%
# Create the X (predictor) variables
X_new = pd.DataFrame(df['new_pixels'].tolist())

# Assign Predictor Variables and Target variables
X = X_new
y_age = df['age'].values
y_gender = df['gender'].values

# split the Variables into Train and Validation sets
y_reg_train, y_reg_val, y_clf_train, y_clf_val, X_train, X_val = train_test_split(y_age,
																				y_gender,
																				X,
																				test_size=0.2,
																				stratify = y_gender,
																				random_state=42)
# Check the shape
y_reg_train.shape, y_reg_val.shape, y_clf_train.shape, y_clf_val.shape, X_train.shape, X_val.shape
# Out:
# ((18964,), (4741,), (18964,), (4741,), (18964, 2304), (4741, 2304))

# %% [markdown]
# # Normalizations
# Before we proceed forward, a necessary step in Data preparation for training is to normalize the pixel data. This ensures that the pixels are in a similar data distribution which will help in faster model convergence in training.

# %%
np.array(df['new_pixels'].tolist()).min()
# Out:
# 0

# %%
np.array(df['new_pixels'].tolist()).max()
# Out:
# 255

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
type(X_val)
# Out:
# pandas.core.frame.DataFrame

# %%
# Normalising the Pixel data for training dataset and then reshaping it to (48,48,1) 
Xmin = 0
Xmax = 255
X_train = X_train.values
# This line normalizes the pixel values. Each pixel value is subtracted by the minimum value (Xmin) and divided by the range of pixel values (Xmax - Xmin). 
# This brings the pixel values to the range [0, 1].
X_train = (X_train - Xmin)/(Xmax-Xmin) 
# This reshapes the normalized X_train array into a 4D array, where each image is represented as a 3D array with dimensions (48, 48, 1). 
# The -1 in the reshape function means that the size of that dimension is inferred from the size of the original array, preserving the number of images. 
# The (48, 48, 1) indicates that each image has a height and width of 48 pixels and a depth of 1 (for grayscale images).
X_train = X_train.reshape(-1,48,48,1)


# similar step is taken for Validation set
X_val = X_val.values
X_val = (X_val - Xmin)/(Xmax-Xmin)
X_val = X_val.reshape(-1,48,48,1)

# %%
X_train.shape

# 48*48 = 2304
# Out:
# (18964, 48, 48, 1)

# %%
# X_train

# %% [markdown]
# # Creating The CNN model Arch

# %% [markdown]
# The model architecture is made using functional API of keras. This method is helpful in **joining two types of output (in this case regression and classification) as a single output** to be fed to the model.
#
# The Model takes 3 parts:
#
#
#
# Input: This layer takes in the input data with shape (48,48,1)
#
# Middle architecture: All the Deep Learning Networks are cascaded over Input layer, i.e., the input layer is joined with subsequent layers in the deep learning model. In this case the architecture consists of:
#
# a single Conv2D layer with 16 node
#
# a single Conv2D layer with 32 nodes followed by Maxpooling2D layer
#
# two conv2D layer with 64 nodes each
#
# a flatten layer
#
# two dense layer of 128 and 32 nodes respectively
#
#
#
# Output: The output of the model consist of two dense layers which corresponds to the necessary task they will perform which are:
#
# a dense layer with 1 node and sigmoid activation which will perform the **gender classification**
#
# a dense layer with 1 node and linear activation which will perform the **age regression prediction**
#
#
#
# For all the other layers, necessary activations were provided. To understand the underlying layers and the parameters involved in the model architecture created above, we will plot the model

# %%
input_layer = keras.Input(shape=(48, 48, 1), name="Input image")

# 16: Specifies the number of filters (or output channels) in the convolutional layer. Each filter learns different features from the input.
# 3: Specifies the size of the convolutional kernel (filter) to be applied. In this case, it's a 3x3 kernel.
# activation="relu": Specifies the activation function to be applied after the convolution operation. In this case, it's the Rectified Linear Unit (ReLU) activation function, which introduces non-linearity to the network.
x = layers.Conv2D(16, 3, activation="relu")(input_layer)

x = layers.Conv2D(32, 3, activation="relu")(x)

# MaxPooling2D layer with pool size 3x3.
x = layers.MaxPooling2D(3)(x)

x = layers.Conv2D(64, 3, activation="relu")(x)
x = layers.Conv2D(64, 3, activation="relu")(x)
x = layers.Flatten()(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dense(32, activation='relu')(x)



out_a = keras.layers.Dense(1, activation='sigmoid', name='g_clf')(x)
out_b = keras.layers.Dense(1, activation='linear', name='a_reg')(x)

model = keras.Model(inputs = input_layer, outputs = [out_a, out_b], name="age_gender_model")

# %%
model.summary()
# Out:
# Model: "age_gender_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Input image (InputLayer)      │ (None, 48, 48, 1)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 46, 46, 16)        │             160 │ Input image[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 44, 44, 32)        │           4,640 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 14, 14, 32)        │               0 │ conv2d_1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 12, 12, 64)        │          18,496 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_3 (Conv2D)             │ (None, 10, 10, 64)        │          36,928 │ conv2d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 6400)              │               0 │ conv2d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │         819,328 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 32)                │           4,128 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ g_clf (Dense)                 │ (None, 1)                 │              33 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ a_reg (Dense)                 │ (None, 1)                 │              33 │ dense_1[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 883,746 (3.37 MB)
#  Trainable params: 883,746 (3.37 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ![model-(1).png](attachment:a1af7c26-645f-4ac2-933d-a7c983f5fec1.png)

# %% [markdown]
# # Model Training
# We compile the model with necessary loss, metrics and optimizers (for each output branch - g_clf and a_reg) and fitted the model for 200 epochs with an earlystopping of patience 25.

# %%
X_train.shape
# Out:
# (18964, 48, 48, 1)

# %%
y_clf_train.shape
# Out:
# (18964,)

# %%
y_reg_train.shape
# Out:
# (18964,)

# %% [markdown]
# Number of batches = Total number of data points / Batch size = 18964 / 256 =74
#
#
# Since we can't have a fraction of a batch, typically, we would have 74 batches per epoch. The final batch might have fewer data points if the total number of data points is not an exact multiple of the batch size.
#
# During each epoch, the model will iterate through these batches, updating the weights based on the gradients computed from each batch. This process repeats for the specified number of epochs until the model converges or reaches the maximum number of epochs.

# %% [markdown]
# ---------------------------------------------
# The model.fit() function trains the model using the data provided in the X_train and [y_clf_train, y_reg_train] parameters. The validation_data parameter is used to evaluate the model's performance on a separate validation dataset (X_val, [y_clf_val, y_reg_val]) after each epoch, but it doesn't train the model on this data.
#
# So, your model is indeed trained on X_train and [y_clf_train, y_reg_train]. The validation_data is used solely for validation purposes during the training process to monitor the model's performance and prevent overfitting.

# %%
# compile the model
model.compile(
	loss = {
		"g_clf": 'binary_crossentropy',
		"a_reg": 'mse'
	},

	metrics = {
		"g_clf": 'accuracy',
		"a_reg": 'mse'
	},

	optimizer = tf.keras.optimizers.Adam(learning_rate=0.003)
)

# create an EarlyStopping instance which will stop if the val_loss doesn't change much in 25 epochs
callback = EarlyStopping(monitor='val_loss',
						patience=25,
						verbose=0)

# train the model 
history = model.fit(X_train, 
					[y_clf_train, y_reg_train],
					batch_size = 256, 
					validation_data= (X_val, [y_clf_val, y_reg_val]), 
					epochs=200, callbacks = [callback])
# Out:
# Epoch 1/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 125ms/step - a_reg_mse: 635.7174 - g_clf_accuracy: 0.4967 - loss: 636.7126 - val_a_reg_mse: 510.7354 - val_g_clf_accuracy: 0.5227 - val_loss: 511.4437
# Epoch 2/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 119ms/step - a_reg_mse: 407.7568 - g_clf_accuracy: 0.5125 - loss: 408.4532 - val_a_reg_mse: 369.5897 - val_g_clf_accuracy: 0.5225 - val_loss: 370.2823
# Epoch 3/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - a_reg_mse: 351.8146 - g_clf_accuracy: 0.5164 - loss: 352.5095 - val_a_reg_mse: 288.5316 - val_g_clf_accuracy: 0.7062 - val_loss: 289.1118
# Epoch 4/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 113ms/step - a_reg_mse: 274.2145 - g_clf_accuracy: 0.7048 - loss: 274.7951 - val_a_reg_mse: 216.6858 - val_g_clf_accuracy: 0.6908 - val_loss: 217.2713
# Epoch 5/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - a_reg_mse: 217.9148 - g_clf_accuracy: 0.6826 - loss: 218.5397 - val_a_reg_mse: 194.6549 - val_g_clf_accuracy: 0.6444 - val_loss: 195.2952
# Epoch 6/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 8s 106ms/step - a_reg_mse: 177.0300 - g_clf_accuracy: 0.6781 - loss: 177.6658 - val_a_reg_mse: 170.7947 - val_g_clf_accuracy: 0.6942 - val_loss: 171.3852
# Epoch 7/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 124ms/step - a_reg_mse: 158.5740 - g_clf_accuracy: 0.6973 - loss: 159.1710 - val_a_reg_mse: 161.2621 - val_g_clf_accuracy: 0.7218 - val_loss: 161.8289
# Epoch 8/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - a_reg_mse: 149.7702 - g_clf_accuracy: 0.7151 - loss: 150.3490 - val_a_reg_mse: 126.9696 - val_g_clf_accuracy: 0.7269 - val_loss: 127.5143
# Epoch 9/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 118ms/step - a_reg_mse: 127.6058 - g_clf_accuracy: 0.7368 - loss: 128.1490 - val_a_reg_mse: 119.8079 - val_g_clf_accuracy: 0.7627 - val_loss: 120.3086
# Epoch 10/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 9s 123ms/step - a_reg_mse: 114.2200 - g_clf_accuracy: 0.7589 - loss: 114.7270 - val_a_reg_mse: 127.1335 - val_g_clf_accuracy: 0.7718 - val_loss: 127.6218
# Epoch 11/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - a_reg_mse: 118.6276 - g_clf_accuracy: 0.7614 - loss: 119.1221 - val_a_reg_mse: 110.7112 - val_g_clf_accuracy: 0.7815 - val_loss: 111.1827
# Epoch 12/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 132ms/step - a_reg_mse: 104.7773 - g_clf_accuracy: 0.7755 - loss: 105.2478 - val_a_reg_mse: 116.6145 - val_g_clf_accuracy: 0.7764 - val_loss: 117.0801
# Epoch 13/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 131ms/step - a_reg_mse: 96.9450 - g_clf_accuracy: 0.7663 - loss: 97.4158 - val_a_reg_mse: 112.7115 - val_g_clf_accuracy: 0.7779 - val_loss: 113.1688
# Epoch 14/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - a_reg_mse: 94.0337 - g_clf_accuracy: 0.7742 - loss: 94.4936 - val_a_reg_mse: 143.7983 - val_g_clf_accuracy: 0.7920 - val_loss: 144.2381
# Epoch 15/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - a_reg_mse: 104.8269 - g_clf_accuracy: 0.7756 - loss: 105.2850 - val_a_reg_mse: 119.2045 - val_g_clf_accuracy: 0.7914 - val_loss: 119.6471
# Epoch 16/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 10s 131ms/step - a_reg_mse: 90.9854 - g_clf_accuracy: 0.7829 - loss: 91.4340 - val_a_reg_mse: 96.4057 - val_g_clf_accuracy: 0.7992 - val_loss: 96.8277
# Epoch 17/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - a_reg_mse: 81.8908 - g_clf_accuracy: 0.7879 - loss: 82.3305 - val_a_reg_mse: 93.0031 - val_g_clf_accuracy: 0.7838 - val_loss: 93.4406
# Epoch 18/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 157ms/step - a_reg_mse: 78.5631 - g_clf_accuracy: 0.7884 - loss: 78.9967 - val_a_reg_mse: 121.5524 - val_g_clf_accuracy: 0.7889 - val_loss: 121.9830
# Epoch 19/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 11s 145ms/step - a_reg_mse: 78.4570 - g_clf_accuracy: 0.7924 - loss: 78.8863 - val_a_reg_mse: 90.0182 - val_g_clf_accuracy: 0.7792 - val_loss: 90.4740
# Epoch 20/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 153ms/step - a_reg_mse: 69.5264 - g_clf_accuracy: 0.7964 - loss: 69.9524 - val_a_reg_mse: 90.0466 - val_g_clf_accuracy: 0.8030 - val_loss: 90.4603
# Epoch 21/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 168ms/step - a_reg_mse: 74.1103 - g_clf_accuracy: 0.8040 - loss: 74.5244 - val_a_reg_mse: 90.2218 - val_g_clf_accuracy: 0.8015 - val_loss: 90.6445
# Epoch 22/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 206ms/step - a_reg_mse: 67.0576 - g_clf_accuracy: 0.8009 - loss: 67.4737 - val_a_reg_mse: 99.7081 - val_g_clf_accuracy: 0.7819 - val_loss: 100.1509
# Epoch 23/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 199ms/step - a_reg_mse: 69.4498 - g_clf_accuracy: 0.7922 - loss: 69.8810 - val_a_reg_mse: 104.1662 - val_g_clf_accuracy: 0.7969 - val_loss: 104.5832
# Epoch 24/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 163ms/step - a_reg_mse: 74.0769 - g_clf_accuracy: 0.8099 - loss: 74.4818 - val_a_reg_mse: 94.1577 - val_g_clf_accuracy: 0.8087 - val_loss: 94.5698
# Epoch 25/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - a_reg_mse: 62.4779 - g_clf_accuracy: 0.8153 - loss: 62.8690 - val_a_reg_mse: 82.8626 - val_g_clf_accuracy: 0.8175 - val_loss: 83.2592
# Epoch 26/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - a_reg_mse: 65.7445 - g_clf_accuracy: 0.8203 - loss: 66.1283 - val_a_reg_mse: 121.4725 - val_g_clf_accuracy: 0.7887 - val_loss: 121.8940
# Epoch 27/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 160ms/step - a_reg_mse: 66.4765 - g_clf_accuracy: 0.8060 - loss: 66.8735 - val_a_reg_mse: 95.7628 - val_g_clf_accuracy: 0.7844 - val_loss: 96.2092
# Epoch 28/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 181ms/step - a_reg_mse: 61.6148 - g_clf_accuracy: 0.8075 - loss: 62.0122 - val_a_reg_mse: 88.6892 - val_g_clf_accuracy: 0.8273 - val_loss: 89.0622
# Epoch 29/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - a_reg_mse: 54.8890 - g_clf_accuracy: 0.8296 - loss: 55.2520 - val_a_reg_mse: 80.7253 - val_g_clf_accuracy: 0.8235 - val_loss: 81.0926
# Epoch 30/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 204ms/step - a_reg_mse: 53.3317 - g_clf_accuracy: 0.8351 - loss: 53.6895 - val_a_reg_mse: 90.5413 - val_g_clf_accuracy: 0.7870 - val_loss: 91.0154
# Epoch 31/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 175ms/step - a_reg_mse: 53.3917 - g_clf_accuracy: 0.8093 - loss: 53.7958 - val_a_reg_mse: 89.5918 - val_g_clf_accuracy: 0.8205 - val_loss: 89.9654
# Epoch 32/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 176ms/step - a_reg_mse: 53.3710 - g_clf_accuracy: 0.8308 - loss: 53.7341 - val_a_reg_mse: 106.5743 - val_g_clf_accuracy: 0.8296 - val_loss: 106.9371
# Epoch 33/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 179ms/step - a_reg_mse: 57.0203 - g_clf_accuracy: 0.8293 - loss: 57.3897 - val_a_reg_mse: 83.0840 - val_g_clf_accuracy: 0.8296 - val_loss: 83.4504
# Epoch 34/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - a_reg_mse: 46.8994 - g_clf_accuracy: 0.8327 - loss: 47.2603 - val_a_reg_mse: 79.8968 - val_g_clf_accuracy: 0.8287 - val_loss: 80.3013
# Epoch 35/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 205ms/step - a_reg_mse: 44.3030 - g_clf_accuracy: 0.8382 - loss: 44.6576 - val_a_reg_mse: 78.2074 - val_g_clf_accuracy: 0.8441 - val_loss: 78.5523
# Epoch 36/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 186ms/step - a_reg_mse: 41.4020 - g_clf_accuracy: 0.8385 - loss: 41.7416 - val_a_reg_mse: 89.4997 - val_g_clf_accuracy: 0.8346 - val_loss: 89.8619
# Epoch 37/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 190ms/step - a_reg_mse: 44.9282 - g_clf_accuracy: 0.8391 - loss: 45.2765 - val_a_reg_mse: 86.5827 - val_g_clf_accuracy: 0.8452 - val_loss: 86.9233
# Epoch 38/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 193ms/step - a_reg_mse: 41.4257 - g_clf_accuracy: 0.8447 - loss: 41.7630 - val_a_reg_mse: 91.9584 - val_g_clf_accuracy: 0.8102 - val_loss: 92.3639
# Epoch 39/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 196ms/step - a_reg_mse: 41.6769 - g_clf_accuracy: 0.8442 - loss: 42.0189 - val_a_reg_mse: 79.8347 - val_g_clf_accuracy: 0.8397 - val_loss: 80.1807
# Epoch 40/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 16s 214ms/step - a_reg_mse: 42.1081 - g_clf_accuracy: 0.8414 - loss: 42.4529 - val_a_reg_mse: 92.9566 - val_g_clf_accuracy: 0.8473 - val_loss: 93.2971
# Epoch 41/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 174ms/step - a_reg_mse: 39.1210 - g_clf_accuracy: 0.8534 - loss: 39.4493 - val_a_reg_mse: 80.2879 - val_g_clf_accuracy: 0.8365 - val_loss: 80.6447
# Epoch 42/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 173ms/step - a_reg_mse: 36.1751 - g_clf_accuracy: 0.8503 - loss: 36.5046 - val_a_reg_mse: 99.4017 - val_g_clf_accuracy: 0.8469 - val_loss: 99.7385
# Epoch 43/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 195ms/step - a_reg_mse: 37.5891 - g_clf_accuracy: 0.8492 - loss: 37.9144 - val_a_reg_mse: 84.7049 - val_g_clf_accuracy: 0.8445 - val_loss: 85.0544
# Epoch 44/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 173ms/step - a_reg_mse: 33.3137 - g_clf_accuracy: 0.8495 - loss: 33.6400 - val_a_reg_mse: 95.1206 - val_g_clf_accuracy: 0.8469 - val_loss: 95.4546
# Epoch 45/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 169ms/step - a_reg_mse: 34.5912 - g_clf_accuracy: 0.8545 - loss: 34.9055 - val_a_reg_mse: 82.3579 - val_g_clf_accuracy: 0.8511 - val_loss: 82.7163
# Epoch 46/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - a_reg_mse: 33.3557 - g_clf_accuracy: 0.8453 - loss: 33.6902 - val_a_reg_mse: 80.5773 - val_g_clf_accuracy: 0.8414 - val_loss: 80.9462
# Epoch 47/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 177ms/step - a_reg_mse: 31.5329 - g_clf_accuracy: 0.8522 - loss: 31.8568 - val_a_reg_mse: 87.4057 - val_g_clf_accuracy: 0.8564 - val_loss: 87.7385
# Epoch 48/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 171ms/step - a_reg_mse: 31.0679 - g_clf_accuracy: 0.8524 - loss: 31.3899 - val_a_reg_mse: 83.0606 - val_g_clf_accuracy: 0.8289 - val_loss: 83.4350
# Epoch 49/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 200ms/step - a_reg_mse: 26.0811 - g_clf_accuracy: 0.8538 - loss: 26.3996 - val_a_reg_mse: 84.7645 - val_g_clf_accuracy: 0.8426 - val_loss: 85.1075
# Epoch 50/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 17s 224ms/step - a_reg_mse: 24.8142 - g_clf_accuracy: 0.8545 - loss: 25.1379 - val_a_reg_mse: 83.6341 - val_g_clf_accuracy: 0.8435 - val_loss: 83.9772
# Epoch 51/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 19s 253ms/step - a_reg_mse: 23.4502 - g_clf_accuracy: 0.8520 - loss: 23.7731 - val_a_reg_mse: 90.0490 - val_g_clf_accuracy: 0.8557 - val_loss: 90.3702
# Epoch 52/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 17s 223ms/step - a_reg_mse: 25.8267 - g_clf_accuracy: 0.8559 - loss: 26.1378 - val_a_reg_mse: 86.2978 - val_g_clf_accuracy: 0.8564 - val_loss: 86.6203
# Epoch 53/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 16s 218ms/step - a_reg_mse: 19.5448 - g_clf_accuracy: 0.8649 - loss: 19.8495 - val_a_reg_mse: 89.5723 - val_g_clf_accuracy: 0.8574 - val_loss: 89.8949
# Epoch 54/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 17s 228ms/step - a_reg_mse: 20.8222 - g_clf_accuracy: 0.8619 - loss: 21.1236 - val_a_reg_mse: 85.9133 - val_g_clf_accuracy: 0.8538 - val_loss: 86.2516
# Epoch 55/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 273ms/step - a_reg_mse: 19.7219 - g_clf_accuracy: 0.8660 - loss: 20.0163 - val_a_reg_mse: 91.9418 - val_g_clf_accuracy: 0.8445 - val_loss: 92.2809
# Epoch 56/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 15s 203ms/step - a_reg_mse: 18.8197 - g_clf_accuracy: 0.8589 - loss: 19.1265 - val_a_reg_mse: 87.6137 - val_g_clf_accuracy: 0.8629 - val_loss: 87.9341
# Epoch 57/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 182ms/step - a_reg_mse: 20.1692 - g_clf_accuracy: 0.8643 - loss: 20.4683 - val_a_reg_mse: 93.3679 - val_g_clf_accuracy: 0.8578 - val_loss: 93.6846
# Epoch 58/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 185ms/step - a_reg_mse: 17.2441 - g_clf_accuracy: 0.8651 - loss: 17.5423 - val_a_reg_mse: 87.3321 - val_g_clf_accuracy: 0.8467 - val_loss: 87.6650
# Epoch 59/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 14s 183ms/step - a_reg_mse: 14.9444 - g_clf_accuracy: 0.8622 - loss: 15.2422 - val_a_reg_mse: 92.4765 - val_g_clf_accuracy: 0.8551 - val_loss: 92.8108
# Epoch 60/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 13s 176ms/step - a_reg_mse: 18.9146 - g_clf_accuracy: 0.8646 - loss: 19.2120 - val_a_reg_mse: 87.5381 - val_g_clf_accuracy: 0.8479 - val_loss: 87.8671

# %% [markdown]
# # Plotting the Losses and Accuracy for Regression and Classification Respectively
# To visualize the losses, we will use history of our model training and plot the necessary metrices.

# %%
# plotting for Gender Classification Accuracy
plt.plot(history.history['g_clf_accuracy'], label = 'training accuracy')
plt.plot(history.history['val_g_clf_accuracy'], label = 'validation accuracy')
plt.title('Gender classification model Accuracy')
plt.xlabel('epoch')
plt.ylabel('Accuracy for gender classification')
plt.legend()
plt.show()

# %%
# plotting the mse loss for age regression 
plt.plot(history.history['a_reg_mse'], label = 'training loss')
plt.plot(history.history['val_a_reg_mse'], label = 'validation loss')
plt.title('Age Estimation model loss')
plt.xlabel('epoch')
plt.ylabel('loss for age estimation')
plt.legend()

plt.show()

# %% [markdown]
# # Model Evaluations

# %%
# valuate the model's performance on the validation dataset
model.evaluate(X_val, [y_clf_val, y_reg_val])
# Out:
# 149/149 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - a_reg_mse: 88.7488 - g_clf_accuracy: 0.8420 - loss: 89.0890
# [87.8670654296875, 87.53805541992188, 0.8479223847389221]

# %% [markdown]
# # Based on results above, val_loss: 221.9182 >> loss: 19.9258, it appears that the model may be overfitting the training data.

# %%
X_val.shape
# Out:
# (4741, 48, 48, 1)

# %% [markdown]
# # Predict Age & Gender from the model - the results are good
# We created a subplot of 3×3 with random indices and predicted the age and gender for the given input image
#
# **The title at the top signifies actual age and gender whereas the title below signifies predicted age and gender.**

# %%
# Define the gender dictionary
gender_dict = {"0": "Male", "1": "Female"}

fig, ax = plt.subplots(3,3, figsize = (10,15))

ax = ax.ravel()

res = random.sample(range(0, X_val.shape[0]), 9)

for i,id in enumerate(res):
	ax[i].imshow(X_val[id])
	ax[i].set_title(f'Age-group: {y_reg_val[id]}, Gender: {gender_dict[str(y_clf_val[id])]}')
	
	pred_Gender, pred_age = model.predict(tf.expand_dims(X_val[id], 0), verbose = 0)
	y_value = np.where(pred_Gender > 0.5, 1,0)
    #  This function call returns an array where elements that satisfy the condition (i.e., where pred_Gender > 0.5) are replaced with 1, and elements that do not satisfy the condition are replaced with 0.
	ax[i].set_xlabel(f'P gender: {gender_dict[str(y_value[0][0])]} , P age: {int(np.round(pred_age,0))}')
	
plt.savefig('prediction_subplot.png')

# %%
X_val[2].shape

# %%
from PIL import Image
import numpy as np

# Read the image
image_path = "jb.jpg" 
image = Image.open(image_path)

# Preprocess the image
# Resize the image to match the input size expected by the model (e.g., 48x48)
image = image.resize((48,48))
image

# %%
# Convert the image to grayscale (if necessary) and normalize the pixel values
# You may need to adjust the preprocessing steps based on your model's requirements
image = image.convert("L")  # Convert to grayscale
image_array = np.array(image) / 255.0  # Normalize pixel values (assuming pixel range is 0-255)

# %%
image_array
# Out:
# array([[0.6627451 , 0.64705882, 0.70588235, ..., 0.90588235, 0.90196078,
#         0.90196078],
#        [0.62745098, 0.67843137, 0.69803922, ..., 0.89411765, 0.88235294,
#         0.8745098 ],
#        [0.48627451, 0.48235294, 0.37254902, ..., 0.84313725, 0.85098039,
#         0.85882353],
#        ...,
#        [0.19215686, 0.18431373, 0.17254902, ..., 0.50196078, 0.63921569,
#         0.61568627],
#        [0.19215686, 0.19607843, 0.20392157, ..., 0.70196078, 0.71764706,
#         0.81176471],
#        [0.13333333, 0.14901961, 0.16862745, ..., 0.58823529, 0.57254902,
#         0.62745098]])

# %%
# Reshape the image to match the input shape expected by the model (add batch dimension)
input_image = np.expand_dims(image_array, axis=-1) 
input_image
# Out:
# array([[[0.6627451 ],
#         [0.64705882],
#         [0.70588235],
#         ...,
#         [0.90588235],
#         [0.90196078],
#         [0.90196078]],
#
#        [[0.62745098],
#         [0.67843137],
#         [0.69803922],
#         ...,
#         [0.89411765],
#         [0.88235294],
#         [0.8745098 ]],
#
#        [[0.48627451],
#         [0.48235294],
#         [0.37254902],
#         ...,
#         [0.84313725],
#         [0.85098039],
#         [0.85882353]],
#
#        ...,
#
#        [[0.19215686],
#         [0.18431373],
#         [0.17254902],
#         ...,
#         [0.50196078],
#         [0.63921569],
#         [0.61568627]],
#
#        [[0.19215686],
#         [0.19607843],
#         [0.20392157],
#         ...,
#         [0.70196078],
#         [0.71764706],
#         [0.81176471]],
#
#        [[0.13333333],
#         [0.14901961],
#         [0.16862745],
#         ...,
#         [0.58823529],
#         [0.57254902],
#         [0.62745098]]])

# %%
input_image.shape
# Out:
# (48, 48, 1)

# %%
# Predict Gender and Age
# pred_gender, pred_age = model.predict(input_image)
# pred_gender, pred_age = model.predict(np.expand_dims(input_image, axis=0))  # Add batch dimension
pred_gender, pred_age = model.predict(tf.expand_dims(input_image, 0), verbose =0 )

# Post-process the predictions
predicted_gender = "Female" if pred_gender > 0.5 else "Male"
predicted_age = int(np.round(pred_age[0][0]))

# Print the predictions
print("Predicted Gender:", predicted_gender)
print("Predicted Age:", predicted_age)
# Out:
# Predicted Gender: Female
# Predicted Age: 16

# %% [markdown]
# # Conclusion
# We saw how we processed a csv dataframe with object type pixel entries, used then with Functional Keras API and created a Model complex enough that it could Classify the Gender and Predict their Age.
